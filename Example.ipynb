# %%
# importing dexter and pandas

import dexter as dxt
import pandas as pd

# %%
# the most used class in dexter is the FrameMap

df1 = pd.DataFrame({'First': [1, 2, 3], 'second': [4, 5, 6]})
df2 = pd.DataFrame({'Third': [7, 8, 9], 'fourth': [10, 11, 12]})

# you can construct a FrameMap from a list of dataframes and a list of their names

dataframes = dxt.FrameMap([df1, df2], ['df1', 'df2'])

# the display method is used to visualize a FrameMap

dataframes.display()
# Out:
# <tr><table><tr style="background-color:white;"><td style="vertical-align:top"><h5 style="text-align:center">df1</h5><br><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First</th>
#       <th>second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td style="vertical-align:top"><h5 style="text-align:center">df2</h5><br><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
# ...

# %%
# alternatively you can create a FrameMap by reading multiple files in a folder with readm functions
dataframes = dxt.readm_csv('./usecases/movielens/ml-25m/', chunksize = 20000)

# %%
# you can easily access the names and dataframes used to create the FrameMap

dataframes.frames
dataframes.names
# Out:
# ['ratings.csv',
#  'movies.csv',
#  'genome-scores.csv',
#  'genome-tags.csv',
#  'links.csv',
#  'tags.csv']

# %%
dataframes.display()
# Out:
# <tr><table><tr style="background-color:white;"><td style="vertical-align:top"><h5 style="text-align:center">ratings.csv</h5><br><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>296</td>
#       <td>5.0</td>
#       <td>1147880044</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>306</td>
#       <td>3.5</td>
#       <td>1147868817</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>307</td>
#       <td>5.0</td>
# ...

# %%
# a few of pandas dataframe methods can be easily applied to a FrameMap
# to properly visualize them in IPython, you can just run them

dataframes.dtypes()
# Out:
# {'frames': [     userId movieId   rating timestamp
#   type  int64   int64  float64     int64,
#        movieId   title  genres
#   type   int64  object  object,
#        movieId  tagId relevance
#   type   int64  int64   float64,
#         tagId     tag
#   type  int64  object,
#        movieId imdbId   tmdbId
#   type   int64  int64  float64,
#        userId movieId     tag timestamp
#   type  int64   int64  object     int64],
#  'names': ['ratings.csv',
#   'movies.csv',
#   'genome-scores.csv',
#   'genome-tags.csv',
#   'links.csv',
#   'tags.csv'],
#  'ratings.csv':      userId movieId   rating timestamp
#  type  int64   int64  float64     int64,
#  'movies.csv':      movieId   title  genres
#  type   int64  object  object,
#  'genome-scores.csv':      movieId  tagId relevance
#  type   int64  int64   float64,
#  'genome-tags.csv':       tagId     tag
#  type  int64  object,
#  'links.csv':      movieId imdbId   tmdbId
#  type   int64  int64  float64,
# ...

# %%
# you can also work with the data from these methods, a FrameList is usually returned
# let's see another example, the head method

dataframes.head()
# Out:
# {'frames': [   userId  movieId  rating   timestamp
#   0       1      296     5.0  1147880044
#   1       1      306     3.5  1147868817
#   2       1      307     5.0  1147868828
#   3       1      665     5.0  1147878820
#   4       1      899     3.5  1147868510,
#      movieId                               title  \
#   0        1                    Toy Story (1995)
#   1        2                      Jumanji (1995)
#   2        3             Grumpier Old Men (1995)
#   3        4            Waiting to Exhale (1995)
#   4        5  Father of the Bride Part II (1995)
#
#                                           genres
#   0  Adventure|Animation|Children|Comedy|Fantasy
#   1                   Adventure|Children|Fantasy
#   2                               Comedy|Romance
#   3                         Comedy|Drama|Romance
#   4                                       Comedy  ,
#      movieId  tagId  relevance
#   0        1      1    0.02875
#   1        1      2    0.02375
# ...

# %%
# and also tail

dataframes.tail()
# Out:
# {'frames': [          userId  movieId  rating   timestamp
#   25000090  162541    50872     4.5  1240953372
#   25000091  162541    55768     2.5  1240951998
#   25000092  162541    56176     2.0  1240950697
#   25000093  162541    58559     4.0  1240953434
#   25000094  162541    63876     5.0  1240952515,
#          movieId                           title                  genres
#   62418   209157                       We (2018)                   Drama
#   62419   209159       Window of the Soul (2001)             Documentary
#   62420   209163                Bad Poems (2018)            Comedy|Drama
#   62421   209169             A Girl Thing (2001)      (no genres listed)
#   62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama,
#             movieId  tagId  relevance
#   15584443   206499   1124    0.11000
#   15584444   206499   1125    0.04850
#   15584445   206499   1126    0.01325
#   15584446   206499   1127    0.14025
# ...

# %%
# now memory usage

dataframes.memory_usage()
# Out:
# {'frames': [              Memory
#   ratings    800003168
#   Index            128
#   userId     200000760
#   movieId    200000760
#   rating     200000760
#   timestamp  200000760,
#              Memory
#   movies   10104440
#   Index         128
#   movieId    499384
#   title     5209972
#   genres    4394956,
#                     Memory
#   genome-scores  374026880
#   Index                128
#   movieId        124675584
#   tagId          124675584
#   relevance      124675584,
#                Memory
#   genome-tags   84751
#   Index           128
#   tagId          9024
#   tag           75599,
#             Memory
#   links    1498280
#   Index        128
#   movieId   499384
#   imdbId    499384
#   tmdbId    499384,
#                 Memory
#   tags       100284123
#   Index            128
#   userId       8746880
#   movieId      8746880
#   tag         74043355
#   timestamp    8746880],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
# ...

# %%
# and even the describe method

dataframes.describe()
# Out:
# {'frames': [             userId       movieId        rating     timestamp
#   count  2.500010e+07  2.500010e+07  2.500010e+07  2.500010e+07
#   mean   8.118928e+04  2.138798e+04  3.533854e+00  1.215601e+09
#   std    4.679172e+04  3.919886e+04  1.060744e+00  2.268758e+08
#   min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
#   25%    4.051000e+04  1.196000e+03  3.000000e+00  1.011747e+09
#   50%    8.091400e+04  2.947000e+03  3.500000e+00  1.198868e+09
#   75%    1.215570e+05  8.623000e+03  4.000000e+00  1.447205e+09
#   max    1.625410e+05  2.091710e+05  5.000000e+00  1.574328e+09,
#                 movieId            title genres
#   count    62423.000000            62423  62423
#   unique            NaN            62325   1639
#   top               NaN  The Void (2016)  Drama
#   freq              NaN                2   9056
#   mean    122220.387646              NaN    NaN
#   std      63264.744844              NaN    NaN
# ...

# %%
# a few other useful methods below

dataframes.multiple_missing()
# Out:
# {'frames': [         userId  movieId  rating  timestamp
#   missing       0        0       0          0],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
#   'links',
#   'tags'],
#  'ratings':          userId  movieId  rating  timestamp
#  missing       0        0       0          0}

# %%
dataframes.shapes()
# Out:
# {'frames': [                   rows  columns
#   ratings        25000095        4
#   movies            62423        3
#   genome-scores  15584448        3
#   genome-tags        1128        2
#   links             62423        3
#   tags            1093360        4],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
#   'links',
#   'tags'],
#  'ratings':                    rows  columns
#  ratings        25000095        4
#  movies            62423        3
#  genome-scores  15584448        3
#  genome-tags        1128        2
#  links             62423        3
#  tags            1093360        4}

# %%
dataframes.nunique()
# Out:
# {'frames': [           non-null
#   userId       162541
#   movieId       59047
#   rating           10
#   timestamp  20115267,
#            non-null
#   movieId     62423
#   title       62325
#   genres       1639,
#              non-null
#   movieId       13816
#   tagId          1128
#   relevance      4000,
#          non-null
#   tagId      1128
#   tag        1128,
#            non-null
#   movieId     62423
#   imdbId      62423
#   tmdbId      62281,
#              non-null
#   userId        14592
#   movieId       45251
#   tag           73050
#   timestamp    907730],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
#   'links',
#   'tags'],
#  'ratings':            non-null
#  userId       162541
#  movieId       59047
#  rating           10
#  timestamp  20115267,
#  'movies':          non-null
#  movieId     62423
#  title       62325
#  genres       1639,
#  'genome-scores':            non-null
#  movieId       13816
# ...

# %%
dataframes
# Out:
# {'frames': [          userId  movieId  rating   timestamp
#   0              1      296     5.0  1147880044
#   1              1      306     3.5  1147868817
#   2              1      307     5.0  1147868828
#   3              1      665     5.0  1147878820
#   4              1      899     3.5  1147868510
#   ...          ...      ...     ...         ...
#   25000090  162541    50872     4.5  1240953372
#   25000091  162541    55768     2.5  1240951998
#   25000092  162541    56176     2.0  1240950697
#   25000093  162541    58559     4.0  1240953434
#   25000094  162541    63876     5.0  1240952515
#
#   [25000095 rows x 4 columns],
#          movieId                               title  \
#   0            1                    Toy Story (1995)
#   1            2                      Jumanji (1995)
#   2            3             Grumpier Old Men (1995)
#   3            4            Waiting to Exhale (1995)
#   4            5  Father of the Bride Part II (1995)
# ...

# %%
dataframes.names
# Out:
# ['ratings', 'movies', 'genome-scores', 'genome-tags', 'links', 'tags']

# %%
# accessing a dataframe by it's key is also pretty easy

dataframes['ratings']
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
# a FrameMap is just a special type of dict

isinstance(dataframes.head(), dict)
# Out:
# True

# %%
# now optimizing dataframe memory usage

dataframes['ratings'].memory_usage()
# Out:
# Index              128
# userId       200000760
# movieId      200000760
# rating       200000760
# timestamp    200000760
# dtype: int64

# %%
dxt.optimize(dataframes['ratings']).memory_usage()
# Out:
# Index              128
# userId       100000380
# movieId      100000380
# rating       100000380
# timestamp    100000380
# dtype: int64

# %%
# and optimizing all dataframes in a FrameMap

dataframes.memory_usage()
# Out:
# {'frames': [              Memory
#   ratings    400001648
#   Index            128
#   userId     100000380
#   movieId    100000380
#   rating     100000380
#   timestamp  100000380,
#              Memory
#   movies   10200589
#   Index         128
#   movieId    499384
#   title     5306121
#   genres    4394956,
#                     Memory
#   genome-scores  374026880
#   Index                128
#   movieId        124675584
#   tagId          124675584
#   relevance      124675584,
#                Memory
#   genome-tags   84751
#   Index           128
#   tagId          9024
#   tag           75599,
#             Memory
#   links    1498280
#   Index        128
#   movieId   499384
#   imdbId    499384
#   tmdbId    499384,
#                 Memory
#   tags       100284123
#   Index            128
#   userId       8746880
#   movieId      8746880
#   tag         74043355
#   timestamp    8746880],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
# ...

# %%
dataframes.optimize().memory_usage()
# Out:
# {'frames': [              Memory
#   ratings    400001648
#   Index            128
#   userId     100000380
#   movieId    100000380
#   rating     100000380
#   timestamp  100000380,
#             Memory
#   movies   5887991
#   Index        128
#   movieId   249692
#   title    5306121
#   genres    332050,
#                     Memory
#   genome-scores  155844608
#   Index                128
#   movieId         62337792
#   tagId           31168896
#   relevance       62337792,
#                Memory
#   genome-tags   77983
#   Index           128
#   tagId          2256
#   tag           75599,
#            Memory
#   links    749204
#   Index       128
#   movieId  249692
#   imdbId   249692
#   tmdbId   249692,
#                Memory
#   tags       24822779
#   Index           128
#   userId      4373440
#   movieId     4373440
#   tag        11702331
#   timestamp   4373440],
#  'names': ['ratings',
#   'movies',
#   'genome-scores',
#   'genome-tags',
#   'links',
# ...

# %%
# as we can see,

print('ratings memory usage reduced to {:.2f}%'.format((400001648 / 400001648) * 100))
print('movies memory usage reduced to {:.2f}%'.format((5887991 / 10200589) * 100))
print('genome-scores memory usage reduced to {:.2f}%'.format((155844608 / 374026880) * 100))
print('genome-tags memory usage reduced to {:.2f}%'.format((77983 / 84751) * 100))
print('links memory usage reduced to {:.2f}%'.format((749204 / 1498280) * 100))
print('tags memory usage reduced to {:.2f}%'.format((24822779 / 100284123) * 100), end='\n\n')

print('total memory usage reduced to {:.2f}%'.format((400001648 + 5887991 + 155844608 + 77983 + 749204 + 24822779) /
                                                (400001648 + 10200589 + 374026880 + 84751 + 1498280 + 100284123) * 100))
# Out:
# ratings memory usage reduced to 100.00%
# movies memory usage reduced to 57.72%
# genome-scores memory usage reduced to 41.67%
# genome-tags memory usage reduced to 92.01%
# links memory usage reduced to 50.00%
# tags memory usage reduced to 24.75%
#
# total memory usage reduced to 66.29%

# %%
# generating multiple csv files for a FrameMap
dataframes.optimize().to_csv()
